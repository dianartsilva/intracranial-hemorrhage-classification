# %% [markdown]
# This script was only used to download the dataset from https://www.kaggle.com/datasets/pedroamaro/smaller-rsnas-ds-ver-10?q=RSNA+Intracranial+Hemorrhage+Detection+in%3Adatasets to the google drive.

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/gdrive/Shareddrives/Depressão de Biomédica/DACO/Project/dataset
# Out:
# /content/gdrive/Shareddrives/Depressão de Biomédica/DACO/Project/dataset

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/Shareddrives/Projeto DACO/dataset"

# %%
# !kaggle datasets download -d pedroamaro/smaller-rsnas-ds-ver-10
# Out:
# ...
# 100% 7.25G/7.25G [00:49<00:00, 146MB/s]
# 100% 7.25G/7.25G [00:49<00:00, 157MB/s]
